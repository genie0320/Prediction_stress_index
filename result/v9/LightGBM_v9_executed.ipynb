# %%
# 1. 사전 환경 준비
# !pip install shap wandb optuna-integration python-dotenv

# %%
import os
import wandb
from dotenv import load_dotenv

# 2. W&B 로그인 (env 파일에 저장된 API 키 로드)
load_dotenv()
wandb_key = os.getenv("WANDB_API_KEY")
if wandb_key and wandb_key != "your_wandb_api_key_here":
    wandb.login(key=wandb_key)
    print("W&B Logged in successfully!")
else:
    print("W&B API key not found in .env. Please set it!")
    wandb.login()  # Interactive prompt fallback
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: Appending key for api.wandb.ai to your netrc file: /Users/admin/.netrc
# wandb: Currently logged in as: genie0320 (genie0320-none) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W&B Logged in successfully!

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from scipy.special import logit, expit

data_dir = "." if os.path.exists("train.csv") else "../.."
train = pd.read_csv(os.path.join(data_dir, "train.csv"))
test = pd.read_csv(os.path.join(data_dir, "test.csv"))
print("Train shape:", train.shape, "Test shape:", test.shape)
# Out:
# Train shape: (3000, 18) Test shape: (3000, 17)

# %%
# ==========================================
# 3. 결측치 처리 및 Data-Centric 보강
# ==========================================
for df in [train, test]:
    df["medical_history"] = df["medical_history"].fillna("none")
    df["family_medical_history"] = df["family_medical_history"].fillna("none")
    df["edu_level"] = df["edu_level"].fillna("Unknown")

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# IterativeImputer를 사용하여 수치형 변수 기반 mean_working 대치 (Train으로만 fit)
numeric_cols_for_imputation = [
    "age",
    "height",
    "weight",
    "cholesterol",
    "systolic_blood_pressure",
    "diastolic_blood_pressure",
    "glucose",
    "bone_density",
    "mean_working",
]

imputer = IterativeImputer(random_state=42, max_iter=20)

# Data Leakage 방지를 위해 Train 데이터로만 Imputer를 학습시킴
train[numeric_cols_for_imputation] = imputer.fit_transform(
    train[numeric_cols_for_imputation]
)
test[numeric_cols_for_imputation] = imputer.transform(test[numeric_cols_for_imputation])

print("mean_working imputed with IterativeImputer.")
# Out:
# mean_working imputed with IterativeImputer.

# %%
# ==========================================
# 4. 파생 변수 추가 (원본 변수는 절대 삭제하지 않음)
# ==========================================
for df in [train, test]:
    # disease_count 파생 변수 (희소성 보완)
    df["medical_disease_count"] = df["medical_history"].apply(
        lambda x: 0 if x == "none" else len(str(x).split(","))
    )
    df["family_disease_count"] = df["family_medical_history"].apply(
        lambda x: 0 if x == "none" else len(str(x).split(","))
    )

    # 비선형 생체 지표 도메인 파생 변수 추가
    df["bmi"] = df["weight"] / ((df["height"] / 100) ** 2)
    df["pulse_pressure"] = (
        df["systolic_blood_pressure"] - df["diastolic_blood_pressure"]
    )
    df["map"] = (df["systolic_blood_pressure"] + 2 * df["diastolic_blood_pressure"]) / 3
    df["glucose_cholesterol_ratio"] = df["glucose"] / (df["cholesterol"] + 1)
    df["overwork_and_poor_sleep"] = (
        (df["mean_working"] >= 12) & (df["sleep_pattern"] == "sleep difficulty")
    ).astype(int)
    df["vascular_bone_risk"] = (
        (df["bone_density"] <= -1.0) & (df["pulse_pressure"] > 80)
    ).astype(int)

# 복합 질환(medical_history) 동적 이진화 플래그 생성 (train 기준으로 추출)
diseases = set()
for col in ["medical_history", "family_medical_history"]:
    for val in train[col].dropna().unique():
        for d in val.split(","):
            diseases.add(d.strip())
diseases.discard("none")
diseases = sorted(list(diseases))

for col, prefix in [("medical_history", "med"), ("family_medical_history", "fam")]:
    for disease in diseases:
        feat_name = f'{prefix}_{disease.lower().replace(" ", "_")}'
        train[feat_name] = train[col].apply(
            lambda x: 1 if disease in [d.strip() for d in x.split(",")] else 0
        )
        test[feat_name] = test[col].apply(
            lambda x: 1 if disease in [d.strip() for d in x.split(",")] else 0
        )

# Ordinal Encoding 매핑
edu_map = {
    "Unknown": 0,
    "high school diploma": 1,
    "bachelors degree": 2,
    "graduate degree": 3,
}
activity_map = {"light": 1, "moderate": 2, "intense": 3}
for df in [train, test]:
    df["edu_level_encoded"] = df["edu_level"].map(edu_map)
    df["activity_encoded"] = df["activity"].map(activity_map)

# 문자열 데이터는 Label Encoding
categorical_cols = [
    "gender",
    "smoke_status",
    "sleep_pattern",
    "activity",
    "edu_level",
    "medical_history",
    "family_medical_history",
]
for col in categorical_cols:
    le = LabelEncoder()
    le.fit(pd.concat([train[col], test[col]]).astype(str))
    train[col] = le.transform(train[col].astype(str))
    test[col] = le.transform(test[col].astype(str))
    train[col] = train[col].astype("category")
    test[col] = test[col].astype("category")

print("Feature Engineering Complete. Train shape:", train.shape)
# Out:
# Feature Engineering Complete. Train shape: (3000, 34)

# %%
x_train = train.drop(["ID", "stress_score"], axis=1)
y_train = train["stress_score"]
x_test = test.drop("ID", axis=1)

# %%
# ==========================================
# 5. SHAP 기반 노이즈 제어 (최하위 3개 제명)
# ==========================================
import shap
import lightgbm as lgb
import matplotlib.pyplot as plt

print("Calculating SHAP values for baseline model feature selection...")

# Baseline LightGBM 학습
baseline_model = lgb.LGBMRegressor(
    objective="regression_l1", random_state=42, verbose=-1, n_jobs=1
)
baseline_model.fit(x_train, y_train)

# SHAP TreeExplainer 기여도 계산
explainer = shap.TreeExplainer(baseline_model)
shap_values = explainer.shap_values(x_train)

if isinstance(shap_values, list):
    shap_avg = np.abs(shap_values[0]).mean(axis=0)
else:
    shap_avg = np.abs(shap_values).mean(axis=0)

shap_imp = pd.Series(shap_avg, index=x_train.columns).sort_values(ascending=False)
print("\n--- SHAP Feature Importances (Absolute Mean) ---")
for feat, val in shap_imp.items():
    print(f"{feat}: {val:.6f}")

plt.figure(figsize=(10, 8))
shap.summary_plot(shap_values, x_train, plot_type="bar", show=False)
plt.tight_layout()
output_dir = "result/v8" if os.path.exists("result/v8") else "."
os.makedirs(output_dir, exist_ok=True)
plt.savefig(os.path.join(output_dir, "shap_summary_plot_v8.png"))
plt.close()

# 최하위 3개 피처 자동 제거
N = 3
features_to_drop = list(shap_imp.tail(N).index)
print(f"\nRemoving bottom {N} features from dataset: {features_to_drop}")
x_train = x_train.drop(
    columns=[f for f in features_to_drop if f in x_train.columns], errors="ignore"
)
x_test = x_test.drop(
    columns=[f for f in features_to_drop if f in x_test.columns], errors="ignore"
)
# Out:
# Calculating SHAP values for baseline model feature selection...
#
# --- SHAP Feature Importances (Absolute Mean) ---
# mean_working: 0.022559
# height: 0.017828
# cholesterol: 0.017555
# weight: 0.016182
# diastolic_blood_pressure: 0.016143
# glucose_cholesterol_ratio: 0.015759
# glucose: 0.014735
# bmi: 0.014353
# bone_density: 0.013353
# map: 0.012561
# age: 0.010147
# pulse_pressure: 0.009196
# systolic_blood_pressure: 0.009119
# edu_level: 0.007391
# smoke_status: 0.007317
# sleep_pattern: 0.006014
# medical_history: 0.004584
# edu_level_encoded: 0.004057
# activity: 0.003927
# family_disease_count: 0.003600
# medical_disease_count: 0.003308
# family_medical_history: 0.002987
# fam_high_blood_pressure: 0.001966
# med_high_blood_pressure: 0.001364
# fam_heart_disease: 0.001163
# fam_diabetes: 0.001152
# med_heart_disease: 0.001117
# gender: 0.000914
# med_diabetes: 0.000898
# vascular_bone_risk: 0.000000
# overwork_and_poor_sleep: 0.000000
# activity_encoded: 0.000000
#
# Removing bottom 3 features from dataset: ['vascular_bone_risk', 'overwork_and_poor_sleep', 'activity_encoded']

# %%
# ==========================================
# 6. Optuna Tuning (XGBoost Single Hyper-Specialization with Logit-Sigmoid Target Transformation)
# ==========================================
import optuna
from optuna_integration.wandb import WeightsAndBiasesCallback
from sklearn.model_selection import KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import xgboost as xgb
import warnings

warnings.filterwarnings("ignore")

epsilon = 1e-5


# Custom Eval Metric for XGBoost inside K-Fold so that validation performance is evaluated in Sigmoid (Original) space.
def mae_sigmoid_eval(y_true, y_pred):
    orig_preds = expit(y_pred)
    orig_labels = expit(y_true)
    mae = np.mean(np.abs(orig_preds - orig_labels))
    return mae


def tune_xgboost(x_train, y_train):
    # Logit transformation of target variable y
    y_train_clipped = np.clip(y_train, epsilon, 1.0 - epsilon)
    y_train_logit = logit(y_train_clipped)

    def objective(trial):
        params = {
            "objective": "reg:absoluteerror",
            "random_state": 42,
            "verbosity": 0,
            "n_jobs": 1,
            "enable_categorical": True,
            "tree_method": "hist",
            "n_estimators": trial.suggest_int("n_estimators", 200, 800),
            "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1, log=True),
            "max_depth": trial.suggest_int("max_depth", 3, 8),
            "min_child_weight": trial.suggest_int("min_child_weight", 10, 50),
            "subsample": trial.suggest_float("subsample", 0.5, 0.9),
            "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 0.9),
            "alpha": trial.suggest_float("alpha", 1e-4, 10.0, log=True),
            "lambda": trial.suggest_float("lambda", 1e-4, 10.0, log=True),
        }

        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        mae_scores, mse_scores, r2_scores = [], [], []

        for train_idx, val_idx in kf.split(x_train, y_train_logit):
            X_tr, y_tr_logit = x_train.iloc[train_idx], y_train_logit.iloc[train_idx]
            X_val, y_val_logit = x_train.iloc[val_idx], y_train_logit.iloc[val_idx]
            y_val_orig = y_train.iloc[
                val_idx
            ]  # Original space target for validation score

            model = xgb.XGBRegressor(**params)

            # Train on logit space
            # fit() 내부의 'eval_metric' 대신 생성자 params로 전달하도록 변경하여 IDE 빨간줄 및 Warning 해결
            model.fit(X_tr, y_tr_logit, eval_set=[(X_val, y_val_logit)], verbose=False)

            # Predict in logit space
            preds_logit = model.predict(X_val)
            # Restore back to original space using sigmoid (expit)
            preds_orig = expit(preds_logit)

            # Core calculation must happen in original y space
            mae_scores.append(mean_absolute_error(y_val_orig, preds_orig))
            mse_scores.append(mean_squared_error(y_val_orig, preds_orig))
            r2_scores.append(r2_score(y_val_orig, preds_orig))

        mean_mae = np.mean(mae_scores)
        mean_mse = np.mean(mse_scores)
        mean_rmse = np.sqrt(mean_mse)
        mean_r2 = np.mean(r2_scores)

        trial.set_user_attr("mse", mean_mse)
        trial.set_user_attr("rmse", mean_rmse)
        trial.set_user_attr("r2", mean_r2)

        # Log metrics to W&B in original target scale
        # wandb.log({"val_mae": mean_mae, "val_mse": mean_mse, "val_rmse": mean_rmse, "val_r2": mean_r2, "trial_number": trial.number})
        return mean_mae

    wandb_kwargs = {
        "project": "stress_index_v9",
        "name": "xgboost_logit_tuning",
        "reinit": True,
    }
    wandbc = WeightsAndBiasesCallback(metric_name="mae", wandb_kwargs=wandb_kwargs)

    study = optuna.create_study(direction="minimize")
    # 100 trials requested
    study.optimize(objective, n_trials=100, callbacks=[wandbc])
    wandb.finish()
    return study.best_params


print("Tuning XGBoost Hyperparameters...")
best_xgb = tune_xgboost(x_train, y_train)
print(f"Best XGBoost Params: {best_xgb}")
# Out:
# Tuning XGBoost Hyperparameters...
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.27.2
# Run data is saved locally in <code>/Users/admin/Documents/dev_src/stress_index/result/v9/wandb/run-20260617_112338-a1zyzrj6</code>
# Syncing run <strong><a href='https://wandb.ai/genie0320-none/stress_index_v9/runs/a1zyzrj6' target="_blank">xgboost_logit_tuning</a></strong> to <a href='https://wandb.ai/genie0320-none/stress_index_v9' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/genie0320-none/stress_index_v9' target="_blank">https://wandb.ai/genie0320-none/stress_index_v9</a>
#  View run at <a href='https://wandb.ai/genie0320-none/stress_index_v9/runs/a1zyzrj6' target="_blank">https://wandb.ai/genie0320-none/stress_index_v9/runs/a1zyzrj6</a>
# [I 2026-06-17 11:23:39,867] A new study created in memory with name: no-name-cc629e9f-24b5-4c11-b22f-2e4803cd4fec
# [I 2026-06-17 11:23:41,131] Trial 0 finished with value: 0.22214350615262987 and parameters: {'n_estimators': 251, 'learning_rate': 0.05080163872196465, 'max_depth': 5, 'min_child_weight': 27, 'subsample': 0.8011273638774122, 'colsample_bytree': 0.8748241657647119, 'alpha': 8.412866432659284, 'lambda': 0.0808730022204419}. Best is trial 0 with value: 0.22214350615262987.
# [I 2026-06-17 11:23:43,446] Trial 1 finished with value: 0.23021981194555757 and parameters: {'n_estimators': 727, 'learning_rate': 0.026846055467972037, 'max_depth': 4, 'min_child_weight': 48, 'subsample': 0.6570749676422237, 'colsample_bytree': 0.7793934131343201, 'alpha': 0.16767869505451394, 'lambda': 0.0007981738924328934}. Best is trial 0 with value: 0.22214350615262987.
# [I 2026-06-17 11:23:44,452] Trial 2 finished with value: 0.23709073223908744 and parameters: {'n_estimators': 312, 'learning_rate': 0.014961196133176846, 'max_depth': 4, 'min_child_weight': 31, 'subsample': 0.7740171920513845, 'colsample_bytree': 0.594589537560877, 'alpha': 0.0266802017303877, 'lambda': 0.7266141495508386}. Best is trial 0 with value: 0.22214350615262987.
# [I 2026-06-17 11:23:45,217] Trial 3 finished with value: 0.236068570218881 and parameters: {'n_estimators': 211, 'learning_rate': 0.020780698786478848, 'max_depth': 4, 'min_child_weight': 41, 'subsample': 0.8806977545826429, 'colsample_bytree': 0.7340138924669097, 'alpha': 9.547708893917521, 'lambda': 0.034379694039291975}. Best is trial 0 with value: 0.22214350615262987.
# [I 2026-06-17 11:23:47,901] Trial 4 finished with value: 0.22001325658857823 and parameters: {'n_estimators': 678, 'learning_rate': 0.028918132312309833, 'max_depth': 8, 'min_child_weight': 36, 'subsample': 0.5195104081960682, 'colsample_bytree': 0.5808012393318642, 'alpha': 0.03147414602924701, 'lambda': 0.00023644317433678988}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:49,551] Trial 5 finished with value: 0.22957440859397255 and parameters: {'n_estimators': 454, 'learning_rate': 0.01788385342519788, 'max_depth': 5, 'min_child_weight': 32, 'subsample': 0.7803586656911616, 'colsample_bytree': 0.7589176547989734, 'alpha': 0.00020896336306184954, 'lambda': 0.00029284392390504767}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:50,430] Trial 6 finished with value: 0.23992360902905463 and parameters: {'n_estimators': 277, 'learning_rate': 0.011727287612255149, 'max_depth': 3, 'min_child_weight': 21, 'subsample': 0.8793189786898762, 'colsample_bytree': 0.7534239221096607, 'alpha': 0.000560043911455214, 'lambda': 0.000998615168109126}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:51,585] Trial 7 finished with value: 0.22985990020732086 and parameters: {'n_estimators': 395, 'learning_rate': 0.04432544491876674, 'max_depth': 4, 'min_child_weight': 35, 'subsample': 0.6605883416353767, 'colsample_bytree': 0.5222075510685904, 'alpha': 0.04271041874158181, 'lambda': 0.00010175379879851854}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:53,940] Trial 8 finished with value: 0.23364488046526904 and parameters: {'n_estimators': 760, 'learning_rate': 0.01274788554440588, 'max_depth': 4, 'min_child_weight': 35, 'subsample': 0.6292382400488636, 'colsample_bytree': 0.6173821894249563, 'alpha': 0.03838913204154221, 'lambda': 0.1442637824059717}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:55,599] Trial 9 finished with value: 0.23159167104462783 and parameters: {'n_estimators': 538, 'learning_rate': 0.031022245876578324, 'max_depth': 3, 'min_child_weight': 10, 'subsample': 0.8528074488974308, 'colsample_bytree': 0.7292306755857079, 'alpha': 0.0005673452375920582, 'lambda': 0.00046241066714392367}. Best is trial 4 with value: 0.22001325658857823.
# [I 2026-06-17 11:23:59,437] Trial 10 finished with value: 0.20091393890966974 and parameters: {'n_estimators': 609, 'learning_rate': 0.08863153072645728, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.5061346140200425, 'colsample_bytree': 0.895228859823266, 'alpha': 0.5483643929064433, 'lambda': 4.098120130211089}. Best is trial 10 with value: 0.20091393890966974.
# [I 2026-06-17 11:24:04,120] Trial 11 finished with value: 0.19744756776461997 and parameters: {'n_estimators': 638, 'learning_rate': 0.08776163823448983, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.5001150310819954, 'colsample_bytree': 0.8955941002677223, 'alpha': 0.6177816792444969, 'lambda': 8.48436507486625}. Best is trial 11 with value: 0.19744756776461997.
# [I 2026-06-17 11:24:08,588] Trial 12 finished with value: 0.19594250194917123 and parameters: {'n_estimators': 608, 'learning_rate': 0.09614961670708293, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.5013600446688704, 'colsample_bytree': 0.8701284498087335, 'alpha': 0.9021988854112828, 'lambda': 9.058133788348997}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:11,845] Trial 13 finished with value: 0.20383400285025438 and parameters: {'n_estimators': 587, 'learning_rate': 0.09797191303181624, 'max_depth': 7, 'min_child_weight': 17, 'subsample': 0.566663141552147, 'colsample_bytree': 0.8339236739646863, 'alpha': 1.1187899622291062, 'lambda': 8.902215975414961}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:14,760] Trial 14 finished with value: 0.19977173352390526 and parameters: {'n_estimators': 483, 'learning_rate': 0.0688525517095169, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.5727901925449008, 'colsample_bytree': 0.8230330959239541, 'alpha': 1.516140615367024, 'lambda': 1.469908965303342}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:17,945] Trial 15 finished with value: 0.20835006822049618 and parameters: {'n_estimators': 660, 'learning_rate': 0.06505859895455635, 'max_depth': 7, 'min_child_weight': 21, 'subsample': 0.5659653103645158, 'colsample_bytree': 0.8385456710582424, 'alpha': 0.24154435126099388, 'lambda': 1.2290783840266644}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:23,108] Trial 16 finished with value: 0.20143779917220273 and parameters: {'n_estimators': 789, 'learning_rate': 0.0737454381863457, 'max_depth': 8, 'min_child_weight': 16, 'subsample': 0.5028527857533422, 'colsample_bytree': 0.8984795266668761, 'alpha': 2.6454035556504465, 'lambda': 7.9071913752160246}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:25,726] Trial 17 finished with value: 0.20715271730472642 and parameters: {'n_estimators': 563, 'learning_rate': 0.04860418776025973, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.6117743679270082, 'colsample_bytree': 0.8067011150545966, 'alpha': 0.0046400066041525105, 'lambda': 0.2899279463010125}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:28,595] Trial 18 finished with value: 0.20661464889734985 and parameters: {'n_estimators': 651, 'learning_rate': 0.09938148115458424, 'max_depth': 7, 'min_child_weight': 21, 'subsample': 0.5426623832230564, 'colsample_bytree': 0.6783061073677853, 'alpha': 0.24587742773327098, 'lambda': 0.009670129912877062}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:32,180] Trial 19 finished with value: 0.2007823242688179 and parameters: {'n_estimators': 500, 'learning_rate': 0.057358416137996304, 'max_depth': 8, 'min_child_weight': 15, 'subsample': 0.7086440368307101, 'colsample_bytree': 0.8573492724464257, 'alpha': 2.6654219730244195, 'lambda': 3.1318869967200262}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:33,855] Trial 20 finished with value: 0.22031781569898126 and parameters: {'n_estimators': 405, 'learning_rate': 0.03690703177503654, 'max_depth': 6, 'min_child_weight': 25, 'subsample': 0.6076839395591086, 'colsample_bytree': 0.7959053296568283, 'alpha': 0.010223248224551505, 'lambda': 0.551795878346067}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:36,765] Trial 21 finished with value: 0.20296808264275393 and parameters: {'n_estimators': 483, 'learning_rate': 0.07384605952586196, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.5664583988309603, 'colsample_bytree': 0.8268713032591046, 'alpha': 1.0727049273781304, 'lambda': 2.214565387781685}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:40,903] Trial 22 finished with value: 0.19878666434307893 and parameters: {'n_estimators': 624, 'learning_rate': 0.07838334604859151, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.5475294029003884, 'colsample_bytree': 0.8614882916548154, 'alpha': 2.3619776655363607, 'lambda': 1.5648667050905298}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:45,537] Trial 23 finished with value: 0.2005181012415886 and parameters: {'n_estimators': 701, 'learning_rate': 0.08289484258861228, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.5364186084140998, 'colsample_bytree': 0.8644889789987683, 'alpha': 0.121151093512244, 'lambda': 9.858793794776023}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:49,087] Trial 24 finished with value: 0.20506682307759921 and parameters: {'n_estimators': 603, 'learning_rate': 0.06121130256047359, 'max_depth': 8, 'min_child_weight': 19, 'subsample': 0.5385822764429806, 'colsample_bytree': 0.8991304895325294, 'alpha': 0.567705092123625, 'lambda': 3.3229022869921967}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:53,402] Trial 25 finished with value: 0.19829382501492895 and parameters: {'n_estimators': 635, 'learning_rate': 0.08022641851043576, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.5035589527536484, 'colsample_bytree': 0.8606526346255704, 'alpha': 4.487381205769769, 'lambda': 0.43628606795190433}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:56,159] Trial 26 finished with value: 0.2063092383132378 and parameters: {'n_estimators': 533, 'learning_rate': 0.08540030394374419, 'max_depth': 6, 'min_child_weight': 13, 'subsample': 0.5035564719415545, 'colsample_bytree': 0.8548039215228651, 'alpha': 4.819344307768386, 'lambda': 0.011808839862282964}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:24:59,821] Trial 27 finished with value: 0.20529628489524124 and parameters: {'n_estimators': 736, 'learning_rate': 0.05703160959274787, 'max_depth': 7, 'min_child_weight': 18, 'subsample': 0.590553655065862, 'colsample_bytree': 0.812807479730423, 'alpha': 0.552646278081344, 'lambda': 0.28969705023057213}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:02,857] Trial 28 finished with value: 0.20787274986873067 and parameters: {'n_estimators': 646, 'learning_rate': 0.09623670928145414, 'max_depth': 8, 'min_child_weight': 24, 'subsample': 0.5269072889439375, 'colsample_bytree': 0.6905531086408097, 'alpha': 0.0909536672479705, 'lambda': 0.03591816533620757}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:06,449] Trial 29 finished with value: 0.20796219930291177 and parameters: {'n_estimators': 577, 'learning_rate': 0.042028450752553015, 'max_depth': 7, 'min_child_weight': 12, 'subsample': 0.5014330376245951, 'colsample_bytree': 0.8839287908799502, 'alpha': 5.586241803320582, 'lambda': 0.1282537010578637}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:10,179] Trial 30 finished with value: 0.2063210001726945 and parameters: {'n_estimators': 685, 'learning_rate': 0.05319471962236982, 'max_depth': 8, 'min_child_weight': 19, 'subsample': 0.5907241910864339, 'colsample_bytree': 0.781925935816578, 'alpha': 0.44882292184495354, 'lambda': 0.6096929253632803}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:14,625] Trial 31 finished with value: 0.19852278369247917 and parameters: {'n_estimators': 629, 'learning_rate': 0.0782757288129484, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.5451930203479882, 'colsample_bytree': 0.8680455437431299, 'alpha': 2.7064243318497985, 'lambda': 4.573732706928622}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:19,331] Trial 32 finished with value: 0.20055581985533238 and parameters: {'n_estimators': 629, 'learning_rate': 0.06896089379574645, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.5472398306199197, 'colsample_bytree': 0.873622642747731, 'alpha': 4.778568693653217, 'lambda': 4.596318835449332}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:23,828] Trial 33 finished with value: 0.20138423275301856 and parameters: {'n_estimators': 716, 'learning_rate': 0.08380671733726372, 'max_depth': 8, 'min_child_weight': 16, 'subsample': 0.5180920787069069, 'colsample_bytree': 0.8517125758920118, 'alpha': 1.2758933836940525, 'lambda': 5.242975525061319}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:26,147] Trial 34 finished with value: 0.2237665731522441 and parameters: {'n_estimators': 561, 'learning_rate': 0.06561576036587859, 'max_depth': 7, 'min_child_weight': 48, 'subsample': 0.5320692341875052, 'colsample_bytree': 0.8688809152275717, 'alpha': 8.870906237775671, 'lambda': 0.8555593927771956}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:29,665] Trial 35 finished with value: 0.21392304333845774 and parameters: {'n_estimators': 751, 'learning_rate': 0.07798667148507138, 'max_depth': 8, 'min_child_weight': 43, 'subsample': 0.673242459246155, 'colsample_bytree': 0.7860620526544468, 'alpha': 3.050591254049323, 'lambda': 0.2866490873192777}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:33,500] Trial 36 finished with value: 0.2016700069365899 and parameters: {'n_estimators': 678, 'learning_rate': 0.08988171204631244, 'max_depth': 7, 'min_child_weight': 12, 'subsample': 0.5865802452330696, 'colsample_bytree': 0.8403926728017307, 'alpha': 0.3150871636938951, 'lambda': 2.3522267201890115}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:36,571] Trial 37 finished with value: 0.20833119419455529 and parameters: {'n_estimators': 526, 'learning_rate': 0.04846349557496618, 'max_depth': 8, 'min_child_weight': 23, 'subsample': 0.629604734290502, 'colsample_bytree': 0.880761732664021, 'alpha': 1.0104326466395448, 'lambda': 5.819226533027509}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:38,453] Trial 38 finished with value: 0.22155520463367306 and parameters: {'n_estimators': 439, 'learning_rate': 0.021647290967239243, 'max_depth': 6, 'min_child_weight': 17, 'subsample': 0.5548917722722, 'colsample_bytree': 0.7636232929392273, 'alpha': 0.0706722871830625, 'lambda': 0.9507327539570446}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:42,343] Trial 39 finished with value: 0.2136084603194396 and parameters: {'n_estimators': 796, 'learning_rate': 0.07525073200929577, 'max_depth': 8, 'min_child_weight': 28, 'subsample': 0.5263480951118202, 'colsample_bytree': 0.8092222518696217, 'alpha': 9.353656133811246, 'lambda': 0.45733702772420554}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:46,716] Trial 40 finished with value: 0.19810467354784408 and parameters: {'n_estimators': 708, 'learning_rate': 0.061885044644140824, 'max_depth': 7, 'min_child_weight': 12, 'subsample': 0.7167873693969667, 'colsample_bytree': 0.8792338766132255, 'alpha': 1.730181820293982, 'lambda': 0.05360716371156477}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:51,150] Trial 41 finished with value: 0.19890079105625547 and parameters: {'n_estimators': 719, 'learning_rate': 0.061299602387872146, 'max_depth': 7, 'min_child_weight': 12, 'subsample': 0.7067941136889813, 'colsample_bytree': 0.8792144092399367, 'alpha': 1.8253070367191855, 'lambda': 0.0023472423425155904}. Best is trial 12 with value: 0.19594250194917123.
# [I 2026-06-17 11:25:55,311] Trial 42 finished with value: 0.1947961794252197 and parameters: {'n_estimators': 640, 'learning_rate': 0.08471551397146856, 'max_depth': 8, 'min_child_weight': 15, 'subsample': 0.8385455291022452, 'colsample_bytree': 0.8425774300297293, 'alpha': 0.7532226777163716, 'lambda': 0.059311985387229316}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:25:58,051] Trial 43 finished with value: 0.20856155236552162 and parameters: {'n_estimators': 681, 'learning_rate': 0.08887260063258542, 'max_depth': 5, 'min_child_weight': 15, 'subsample': 0.7986392822611, 'colsample_bytree': 0.8430074948733118, 'alpha': 0.771535239715342, 'lambda': 0.05577834595290321}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:01,539] Trial 44 finished with value: 0.19696162792056798 and parameters: {'n_estimators': 597, 'learning_rate': 0.09798118847485003, 'max_depth': 7, 'min_child_weight': 10, 'subsample': 0.8968640619372631, 'colsample_bytree': 0.8911881475280955, 'alpha': 0.19182736054706503, 'lambda': 0.11210036448050609}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:04,477] Trial 45 finished with value: 0.20130372273951766 and parameters: {'n_estimators': 597, 'learning_rate': 0.09827437880674322, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.8478416817227116, 'colsample_bytree': 0.8881774414969595, 'alpha': 0.17708732543980568, 'lambda': 0.016722747936403704}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:05,884] Trial 46 finished with value: 0.20979636729856335 and parameters: {'n_estimators': 312, 'learning_rate': 0.069492394958863, 'max_depth': 7, 'min_child_weight': 20, 'subsample': 0.8966689827702197, 'colsample_bytree': 0.5104883301979176, 'alpha': 0.38995262861756325, 'lambda': 0.09889887721741007}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:09,291] Trial 47 finished with value: 0.20015987992624443 and parameters: {'n_estimators': 663, 'learning_rate': 0.09296889040979078, 'max_depth': 7, 'min_child_weight': 17, 'subsample': 0.8480508005114826, 'colsample_bytree': 0.8272412254940105, 'alpha': 0.020456487341726576, 'lambda': 0.005222317860812916}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:12,088] Trial 48 finished with value: 0.20696006006439527 and parameters: {'n_estimators': 581, 'learning_rate': 0.05322553371286297, 'max_depth': 6, 'min_child_weight': 11, 'subsample': 0.7553271607715083, 'colsample_bytree': 0.8930423152270308, 'alpha': 0.1740560050291166, 'lambda': 0.03077286734033731}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:16,355] Trial 49 finished with value: 0.19693425796618064 and parameters: {'n_estimators': 768, 'learning_rate': 0.08818080719355414, 'max_depth': 7, 'min_child_weight': 15, 'subsample': 0.8700088776598689, 'colsample_bytree': 0.8395765303282334, 'alpha': 0.7543427612428544, 'lambda': 0.05085717803662432}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:17,441] Trial 50 finished with value: 0.21013416194895904 and parameters: {'n_estimators': 201, 'learning_rate': 0.09960155622592091, 'max_depth': 7, 'min_child_weight': 16, 'subsample': 0.8261877660640795, 'colsample_bytree': 0.8175555271259557, 'alpha': 0.06728798280154673, 'lambda': 0.19561896842642906}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:21,736] Trial 51 finished with value: 0.19780953669548035 and parameters: {'n_estimators': 767, 'learning_rate': 0.0872776588082571, 'max_depth': 7, 'min_child_weight': 15, 'subsample': 0.8718870054359698, 'colsample_bytree': 0.8446133507976238, 'alpha': 0.9057423155001, 'lambda': 0.0731872726115482}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:26,107] Trial 52 finished with value: 0.1969392212624351 and parameters: {'n_estimators': 772, 'learning_rate': 0.08859488889919548, 'max_depth': 7, 'min_child_weight': 15, 'subsample': 0.8673278775374283, 'colsample_bytree': 0.8436095530806412, 'alpha': 0.9743987435368054, 'lambda': 0.022178949661998966}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:30,119] Trial 53 finished with value: 0.1993997588228186 and parameters: {'n_estimators': 770, 'learning_rate': 0.09025935598480354, 'max_depth': 7, 'min_child_weight': 18, 'subsample': 0.8267275689378852, 'colsample_bytree': 0.8329251197546128, 'alpha': 0.2342936856193909, 'lambda': 0.023225572608429675}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:32,876] Trial 54 finished with value: 0.2035503723710775 and parameters: {'n_estimators': 558, 'learning_rate': 0.07264501766253265, 'max_depth': 6, 'min_child_weight': 10, 'subsample': 0.8997594504005103, 'colsample_bytree': 0.7996772844951833, 'alpha': 0.686323620014546, 'lambda': 0.002541716439972592}. Best is trial 42 with value: 0.1947961794252197.
# [I 2026-06-17 11:26:36,905] Trial 55 finished with value: 0.19382932555069526 and parameters: {'n_estimators': 742, 'learning_rate': 0.08275046446446378, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.8726158035354119, 'colsample_bytree': 0.57348498020328, 'alpha': 0.38733949118450495, 'lambda': 0.006600534984788567}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:39,096] Trial 56 finished with value: 0.22412056463837624 and parameters: {'n_estimators': 750, 'learning_rate': 0.08202373034703482, 'max_depth': 3, 'min_child_weight': 14, 'subsample': 0.8681555320098321, 'colsample_bytree': 0.5774012990473958, 'alpha': 0.11879579649270562, 'lambda': 0.006117709253320793}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:43,147] Trial 57 finished with value: 0.19635095994184412 and parameters: {'n_estimators': 783, 'learning_rate': 0.06802039146598254, 'max_depth': 8, 'min_child_weight': 15, 'subsample': 0.8259375953661292, 'colsample_bytree': 0.5470807277595269, 'alpha': 0.28017436982211036, 'lambda': 0.0012339262667779634}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:46,955] Trial 58 finished with value: 0.21737603969097136 and parameters: {'n_estimators': 785, 'learning_rate': 0.010260706099168815, 'max_depth': 8, 'min_child_weight': 22, 'subsample': 0.8259499627410551, 'colsample_bytree': 0.5561686197316645, 'alpha': 0.3921785145191941, 'lambda': 0.0007226060362070046}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:50,654] Trial 59 finished with value: 0.2020574899411202 and parameters: {'n_estimators': 735, 'learning_rate': 0.06644586122520953, 'max_depth': 8, 'min_child_weight': 19, 'subsample': 0.8106427294948897, 'colsample_bytree': 0.6109751152263573, 'alpha': 0.00014207685269248125, 'lambda': 0.00014732047729477824}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:53,514] Trial 60 finished with value: 0.2106132538703084 and parameters: {'n_estimators': 777, 'learning_rate': 0.0727637638387976, 'max_depth': 5, 'min_child_weight': 16, 'subsample': 0.8578572622674872, 'colsample_bytree': 0.6517543376404806, 'alpha': 0.29864381616039687, 'lambda': 0.0017202369106388419}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:26:57,610] Trial 61 finished with value: 0.19506366449862717 and parameters: {'n_estimators': 800, 'learning_rate': 0.09152455639257495, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.8841393153429079, 'colsample_bytree': 0.5437030747306713, 'alpha': 0.0015955656200890812, 'lambda': 0.005225876904030561}. Best is trial 55 with value: 0.19382932555069526.
# [I 2026-06-17 11:27:01,704] Trial 62 finished with value: 0.19297085579852263 and parameters: {'n_estimators': 800, 'learning_rate': 0.08170751336432608, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.8838781302527621, 'colsample_bytree': 0.5415922350452326, 'alpha': 0.0017229810342755311, 'lambda': 0.006451072726733352}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:05,532] Trial 63 finished with value: 0.1945480107892553 and parameters: {'n_estimators': 749, 'learning_rate': 0.08178832137381463, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.8882164635616512, 'colsample_bytree': 0.5399498721907324, 'alpha': 0.001695259194306882, 'lambda': 0.0043728649021947535}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:09,465] Trial 64 finished with value: 0.20009185491293668 and parameters: {'n_estimators': 793, 'learning_rate': 0.05753249206320288, 'max_depth': 8, 'min_child_weight': 18, 'subsample': 0.884132223172881, 'colsample_bytree': 0.5457808188426683, 'alpha': 0.00179733372000491, 'lambda': 0.00449989829394877}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:13,333] Trial 65 finished with value: 0.1947992473791043 and parameters: {'n_estimators': 742, 'learning_rate': 0.07680845442786391, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.8387053538568896, 'colsample_bytree': 0.5402787047289054, 'alpha': 0.0010923649494326624, 'lambda': 0.0011487932795646132}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:17,182] Trial 66 finished with value: 0.19397767523805298 and parameters: {'n_estimators': 741, 'learning_rate': 0.08083508390114894, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.8869558396739148, 'colsample_bytree': 0.5288554546884024, 'alpha': 0.0007621992018874557, 'lambda': 0.00846115290987954}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:21,002] Trial 67 finished with value: 0.19634285234640042 and parameters: {'n_estimators': 735, 'learning_rate': 0.07976984638190882, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.8385461628203176, 'colsample_bytree': 0.5291141175547943, 'alpha': 0.0005380806162372664, 'lambda': 0.009661313501876238}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:24,348] Trial 68 finished with value: 0.20024870562841496 and parameters: {'n_estimators': 703, 'learning_rate': 0.07414790182557458, 'max_depth': 8, 'min_child_weight': 20, 'subsample': 0.8865066299904963, 'colsample_bytree': 0.5002871674920197, 'alpha': 0.0011547832548289253, 'lambda': 0.0028855159749311353}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:28,344] Trial 69 finished with value: 0.2082855966202418 and parameters: {'n_estimators': 748, 'learning_rate': 0.01485878434848038, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.857946046298171, 'colsample_bytree': 0.5749324639491441, 'alpha': 0.003316049255632417, 'lambda': 0.0004255943173923605}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:31,848] Trial 70 finished with value: 0.19921705121060213 and parameters: {'n_estimators': 690, 'learning_rate': 0.08197158892760174, 'max_depth': 8, 'min_child_weight': 17, 'subsample': 0.8008638009835052, 'colsample_bytree': 0.5273257204457001, 'alpha': 0.0004332731731265601, 'lambda': 0.007009754301198492}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:34,924] Trial 71 finished with value: 0.2133051241416733 and parameters: {'n_estimators': 727, 'learning_rate': 0.08326256948651412, 'max_depth': 8, 'min_child_weight': 50, 'subsample': 0.8808390919581949, 'colsample_bytree': 0.5609170332023073, 'alpha': 0.0011105434633610321, 'lambda': 0.0036459433014666806}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:39,089] Trial 72 finished with value: 0.19411577765802543 and parameters: {'n_estimators': 741, 'learning_rate': 0.07129265580938078, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.836891045650657, 'colsample_bytree': 0.6008471482822005, 'alpha': 0.0029517912621897235, 'lambda': 0.014481016388026157}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:43,378] Trial 73 finished with value: 0.19602481323093177 and parameters: {'n_estimators': 799, 'learning_rate': 0.0634200368750509, 'max_depth': 8, 'min_child_weight': 14, 'subsample': 0.8397274337755147, 'colsample_bytree': 0.5963226082004144, 'alpha': 0.0038812077871362653, 'lambda': 0.013836591108240011}. Best is trial 62 with value: 0.19297085579852263.
# [I 2026-06-17 11:27:47,392] Trial 74 finished with value: 0.19208819151550532 and parameters: {'n_estimators': 752, 'learning_rate': 0.07593153293609246, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8141433276752064, 'colsample_bytree': 0.5325916595804623, 'alpha': 0.000309742721013771, 'lambda': 0.007664545683654789}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:27:51,424] Trial 75 finished with value: 0.1967941734925906 and parameters: {'n_estimators': 752, 'learning_rate': 0.07036599338462957, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7840043046399848, 'colsample_bytree': 0.5639880098964161, 'alpha': 0.0002857447997232543, 'lambda': 0.008600473958599591}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:27:55,115] Trial 76 finished with value: 0.19452905952205263 and parameters: {'n_estimators': 663, 'learning_rate': 0.07630677561117488, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8146705064776775, 'colsample_bytree': 0.5923528326642997, 'alpha': 0.007050944771811975, 'lambda': 0.0012113340095232959}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:27:58,827] Trial 77 finished with value: 0.19561223926146826 and parameters: {'n_estimators': 664, 'learning_rate': 0.05876188016696886, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8138394959262047, 'colsample_bytree': 0.5927236649586576, 'alpha': 0.006690080773781368, 'lambda': 0.015273885916564525}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:02,818] Trial 78 finished with value: 0.196193122053047 and parameters: {'n_estimators': 718, 'learning_rate': 0.06473185172509893, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7762745388335188, 'colsample_bytree': 0.6401763654355703, 'alpha': 0.0025200397859200694, 'lambda': 0.0037713217760426535}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:06,614] Trial 79 finished with value: 0.1972191379249096 and parameters: {'n_estimators': 701, 'learning_rate': 0.053005807687212136, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.7524018885942022, 'colsample_bytree': 0.5182967157187627, 'alpha': 0.0008362248971592321, 'lambda': 0.0016889975333611686}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:09,778] Trial 80 finished with value: 0.20998461818724873 and parameters: {'n_estimators': 649, 'learning_rate': 0.07775311230160416, 'max_depth': 8, 'min_child_weight': 39, 'subsample': 0.8610256817660871, 'colsample_bytree': 0.6226594285950838, 'alpha': 0.009000950180280111, 'lambda': 0.0077565981984490774}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:13,953] Trial 81 finished with value: 0.19580322035729886 and parameters: {'n_estimators': 741, 'learning_rate': 0.07574219302871364, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.8445666974527911, 'colsample_bytree': 0.5326349569366586, 'alpha': 0.0007041941951994329, 'lambda': 0.0006710885429289208}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:19,004] Trial 82 finished with value: 0.19474022941301267 and parameters: {'n_estimators': 759, 'learning_rate': 0.07194981875820826, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8137983845300303, 'colsample_bytree': 0.7116834148948913, 'alpha': 0.00033028772396257404, 'lambda': 0.0010782828563571962}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:22,832] Trial 83 finished with value: 0.19554215798507132 and parameters: {'n_estimators': 673, 'learning_rate': 0.06962218522936914, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.7869658891163905, 'colsample_bytree': 0.5696398487076751, 'alpha': 0.000294811590942049, 'lambda': 0.0018894797875566877}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:27,254] Trial 84 finished with value: 0.19638112900555132 and parameters: {'n_estimators': 759, 'learning_rate': 0.08409232163484494, 'max_depth': 8, 'min_child_weight': 16, 'subsample': 0.8139290709249843, 'colsample_bytree': 0.6919285515168413, 'alpha': 0.00012341063984811786, 'lambda': 0.0032395526786700244}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:31,121] Trial 85 finished with value: 0.194175455395331 and parameters: {'n_estimators': 617, 'learning_rate': 0.09334273097519145, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.7573459267851737, 'colsample_bytree': 0.7277891046175542, 'alpha': 0.00036207233170818014, 'lambda': 0.011242239904404355}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:35,101] Trial 86 finished with value: 0.19441559963772695 and parameters: {'n_estimators': 617, 'learning_rate': 0.09247769655869623, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.7640788564395786, 'colsample_bytree': 0.733773491075132, 'alpha': 0.0003908635737819409, 'lambda': 0.011840971690737943}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:38,822] Trial 87 finished with value: 0.19362017466465634 and parameters: {'n_estimators': 617, 'learning_rate': 0.09279745225979931, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.759808888524535, 'colsample_bytree': 0.58725062719437, 'alpha': 0.00018250613234827587, 'lambda': 0.01148711518291357}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:42,398] Trial 88 finished with value: 0.19246042314261197 and parameters: {'n_estimators': 614, 'learning_rate': 0.09417226733467073, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.7618366546084513, 'colsample_bytree': 0.5908955338465022, 'alpha': 0.0001866557407633917, 'lambda': 0.010912879744025682}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:46,295] Trial 89 finished with value: 0.19429550280143815 and parameters: {'n_estimators': 609, 'learning_rate': 0.09416907085652068, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.761342059847229, 'colsample_bytree': 0.7487174026957945, 'alpha': 0.00024850918784840095, 'lambda': 0.02249591299181556}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:49,871] Trial 90 finished with value: 0.19772530065347751 and parameters: {'n_estimators': 557, 'learning_rate': 0.09464061765690103, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.7383520296260635, 'colsample_bytree': 0.7501464930167064, 'alpha': 0.0002114052951577566, 'lambda': 0.019030331917987316}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:53,781] Trial 91 finished with value: 0.1958971936387817 and parameters: {'n_estimators': 613, 'learning_rate': 0.0937654615770042, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.7591494176723161, 'colsample_bytree': 0.7333967246794151, 'alpha': 0.0001647760459831703, 'lambda': 0.01190277680054753}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:28:57,204] Trial 92 finished with value: 0.19677453193609915 and parameters: {'n_estimators': 521, 'learning_rate': 0.087117970013836, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.736644031782128, 'colsample_bytree': 0.7176672411212928, 'alpha': 0.00019799744416410187, 'lambda': 0.030393294100814577}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:01,175] Trial 93 finished with value: 0.19522472019145884 and parameters: {'n_estimators': 617, 'learning_rate': 0.09933336967764837, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7691336778527378, 'colsample_bytree': 0.7452959889761823, 'alpha': 0.00010479970854081869, 'lambda': 0.011319557949873547}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:04,719] Trial 94 finished with value: 0.1962500302969416 and parameters: {'n_estimators': 600, 'learning_rate': 0.09243443528367447, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.7214809473912593, 'colsample_bytree': 0.6107325169531739, 'alpha': 0.0004613641519124389, 'lambda': 0.026855231775026765}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:08,995] Trial 95 finished with value: 0.19495252466181914 and parameters: {'n_estimators': 696, 'learning_rate': 0.09539621120783888, 'max_depth': 8, 'min_child_weight': 13, 'subsample': 0.7418467034903313, 'colsample_bytree': 0.7662176306121745, 'alpha': 0.00036874278253446835, 'lambda': 0.03934134355290647}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:12,670] Trial 96 finished with value: 0.19659578588873144 and parameters: {'n_estimators': 575, 'learning_rate': 0.08606795998267029, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7640613788641979, 'colsample_bytree': 0.7734261195277348, 'alpha': 0.00023781046419757965, 'lambda': 0.019779916725118207}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:16,373] Trial 97 finished with value: 0.1958625518325965 and parameters: {'n_estimators': 638, 'learning_rate': 0.09376557511722818, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6951374465986674, 'colsample_bytree': 0.5840152256111147, 'alpha': 0.0006133417480433015, 'lambda': 0.006373961902987062}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:18,641] Trial 98 finished with value: 0.21058776171386243 and parameters: {'n_estimators': 372, 'learning_rate': 0.025840593522259328, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.7230763265408828, 'colsample_bytree': 0.7215721807908942, 'alpha': 0.00017621248785052265, 'lambda': 0.010336861771410338}. Best is trial 74 with value: 0.19208819151550532.
# [I 2026-06-17 11:29:21,955] Trial 99 finished with value: 0.1950968636329969 and parameters: {'n_estimators': 589, 'learning_rate': 0.07847742297717278, 'max_depth': 8, 'min_child_weight': 12, 'subsample': 0.7932172291190834, 'colsample_bytree': 0.5521534087792307, 'alpha': 0.0007918483066123663, 'lambda': 0.01525237133595101}. Best is trial 74 with value: 0.19208819151550532.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>alpha</td><td>▁▁▁▁▁▂▁▁▂▁▂▃▂▁█▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>colsample_bytree</td><td>█▃▆▆█▄▆▇██▇▄█▆█▆█▇█▁▇▇▆▂▂▂▂▂▁▃▂▃▃▅▅▃▃▅▆▂</td></tr><tr><td>lambda</td><td>▁▁▁▁▄█▂▁▁▃▃▂▄▁▁▅▅▁▃▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>learning_rate</td><td>▂▂▂▁▁▇█▅▄▅▆▇█▆▅▂▅▇█▄▆▇▅▆▇▆▁▇▆▅▆▆▆▇██▇▇█▆</td></tr><tr><td>mae</td><td>▅█▅█▆▂▁▁▃▂▃▂▆▂▃▄▂▁▃▃▃▁▂▃▁▁▃▄▁▁▁▁▁▁▁▁▂▁▁▁</td></tr><tr><td>max_depth</td><td>▂▄▁██▇█▇██▇▇█▅██▇▅▇▇▇▇▇█████████████████</td></tr><tr><td>min_child_weight</td><td>▄▅▃▆▆▂▂▃▂▂▂▄█▇▁▃▂▁▂▂▁▂▂▂▃▂▂▂▃▁▁▁▁▆▂▁▂▁▁▁</td></tr><tr><td>n_estimators</td><td>▁▇▁▅▆▆█▄▄▆▆▆▇▇▅█▇▇▂▆█▅▇▇█▇█▇▇▇▆▇▆▇▆▆▅▆▇▆</td></tr><tr><td>subsample</td><td>█▄▃▁▁▃▂▂▂▃▃▂▂▂▁▇▇▅▇█▇▇▆██▇▆▆▆▆▇▆▅▆▆▅▆▆▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>alpha</td><td>0.00079</td></tr><tr><td>colsample_bytree</td><td>0.55215</td></tr><tr><td>lambda</td><td>0.01525</td></tr><tr><td>learning_rate</td><td>0.07848</td></tr><tr><td>mae</td><td>0.1951</td></tr><tr><td>max_depth</td><td>8</td></tr><tr><td>min_child_weight</td><td>12</td></tr><tr><td>n_estimators</td><td>589</td></tr><tr><td>subsample</td><td>0.79322</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">xgboost_logit_tuning</strong> at: <a href='https://wandb.ai/genie0320-none/stress_index_v9/runs/a1zyzrj6' target="_blank">https://wandb.ai/genie0320-none/stress_index_v9/runs/a1zyzrj6</a><br> View project at: <a href='https://wandb.ai/genie0320-none/stress_index_v9' target="_blank">https://wandb.ai/genie0320-none/stress_index_v9</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260617_112338-a1zyzrj6/logs</code>
# Best XGBoost Params: {'n_estimators': 752, 'learning_rate': 0.07593153293609246, 'max_depth': 8, 'min_child_weight': 11, 'subsample': 0.8141433276752064, 'colsample_bytree': 0.5325916595804623, 'alpha': 0.000309742721013771, 'lambda': 0.007664545683654789}

# %%
# ==========================================
# 7. Seed Averaging (XGBoost Spec) on Target Logit Space
# ==========================================
def train_with_seeds(x_train, y_train, x_test, best_params, seeds=[42, 2026, 777]):
    # Pre-transform target y_train
    y_train_clipped = np.clip(y_train, epsilon, 1.0 - epsilon)
    y_train_logit = logit(y_train_clipped)

    oof_preds_orig = np.zeros(len(x_train))
    test_preds_orig = np.zeros(len(x_test))
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for fold, (train_idx, val_idx) in enumerate(kf.split(x_train, y_train_logit)):
        X_tr, y_tr_logit = x_train.iloc[train_idx].copy(), y_train_logit.iloc[train_idx]
        X_val, y_val_logit = x_train.iloc[val_idx].copy(), y_train_logit.iloc[val_idx]

        fold_val_preds_orig = np.zeros(len(X_val))
        fold_test_preds_orig = np.zeros(len(x_test))

        for seed in seeds:
            params = best_params.copy()
            params.update(
                {
                    "objective": "reg:absoluteerror",
                    "random_state": seed,
                    "verbosity": 0,
                    "enable_categorical": True,
                    "tree_method": "hist",
                    "n_jobs": 1,
                }
            )

            model = xgb.XGBRegressor(**params)
            # Train model in Logit space
            model.fit(X_tr, y_tr_logit, eval_set=[(X_val, y_val_logit)], verbose=False)

            # Predict logit and transform back to original scale
            val_pred_orig = expit(model.predict(X_val))
            test_pred_orig = expit(model.predict(x_test))

            fold_val_preds_orig += val_pred_orig / len(seeds)
            fold_test_preds_orig += test_pred_orig / len(seeds)

        oof_preds_orig[val_idx] = fold_val_preds_orig
        test_preds_orig += fold_test_preds_orig / 5

    mae = mean_absolute_error(y_train, oof_preds_orig)
    print(f"[XGBoost Single] Seed Averaged OOF MAE: {mae:.6f}")
    return oof_preds_orig, test_preds_orig


oof_xgb, test_xgb = train_with_seeds(x_train, y_train, x_test, best_xgb)

final_oof_clipped = np.clip(oof_xgb, 0.0, 1.0)
print(f"Final Clipped OOF MAE: {mean_absolute_error(y_train, final_oof_clipped):.6f}")

test_preds = np.clip(test_xgb, 0.0, 1.0)
# Out:
# [XGBoost Single] Seed Averaged OOF MAE: 0.190593
# Final Clipped OOF MAE: 0.190593

# %%
submission = pd.read_csv(os.path.join(data_dir, "sample_submission.csv"))
submission["stress_score"] = test_preds
output_dir = "result/v9" if os.path.exists("result/v9") else "."
os.makedirs(output_dir, exist_ok=True)
submission.to_csv(os.path.join(output_dir, "submit_09.csv"), index=False)
print("Submission saved to submit_09.csv")
# Out:
# Submission saved to submit_09.csv
